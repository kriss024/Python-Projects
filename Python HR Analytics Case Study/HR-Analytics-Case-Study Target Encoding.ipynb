# %%
import pandas as pd  
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
# %matplotlib inline

# %%
dane = pd.read_csv("general_data.csv")
dane.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dane.dropna(inplace = True)

# %%
dane.describe(include=[np.object])
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4382           4382                    4382           4382   4382
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3677           3109                    2865           1806   2626
#
#                 JobRole MaritalStatus Over18
# count              4382          4382   4382
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                975          2007   4382

# %%
dane.drop("Over18", axis=1, inplace=True)

# %%
dane.describe(include=[np.number])
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0  2207.804884
# std       9.137272          8.105396     1.024728            0.0  1271.688783
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1108.250000
# 50%      36.000000          7.000000     3.000000            1.0  2208.500000
# 75%      43.000000         14.000000     4.000000            1.0  3308.750000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4382.000000    4382.000000         4382.000000        4382.000000
# mean      2.063898   65061.702419            2.693291          15.210634
# ...

# %%
dane.drop(["EmployeeID", "EmployeeCount", "StandardHours"], axis=1, inplace=True)

# %%
c = dane["Attrition"].value_counts()
f = pd.DataFrame(c)
display(f)
# Out:
#      Attrition
# No        3677
# Yes        705

# %%
dict = {'Yes' : 1, 'No' : 0} 
dane['Attrition'].replace(dict, inplace=True)

# %%
def Target_Encoding(x,y,data):
    agg = data.groupby(x)[y].mean()
    dict = agg.to_dict()
    return dict

# %%
dict = Target_Encoding('BusinessTravel','Attrition',dane)
dane['BusinessTravel'].replace(dict, inplace=True)

dict = Target_Encoding('Department','Attrition',dane)
dane['Department'].replace(dict, inplace=True)

dict = Target_Encoding('EducationField','Attrition',dane)
dane['EducationField'].replace(dict, inplace=True)

dict = Target_Encoding('Gender','Attrition',dane)
dane['Gender'].replace(dict, inplace=True)

dict = Target_Encoding('JobRole','Attrition',dane)
dane['JobRole'].replace(dict, inplace=True)

dict = Target_Encoding('MaritalStatus','Attrition',dane)
dane['MaritalStatus'].replace(dict, inplace=True)

dane.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0        0.149566    0.151128                 6          2
# 1   31          1        0.247273    0.156719                10          1
# 2   32          0        0.247273    0.156719                17          4
# 3   38          0        0.080357    0.156719                 2          5
# 4   32          0        0.149566    0.156719                10          1
#
#    EducationField    Gender  JobLevel   JobRole  MaritalStatus  MonthlyIncome  \
# 0        0.166667  0.152620         1  0.143959       0.125062         131160
# 1        0.166667  0.152620         1  0.181193       0.253381          41890
# 2        0.122951  0.166413         4  0.169231       0.125062         193280
# 3        0.166667  0.166413         3  0.134615       0.125062          83210
# 4        0.160289  0.166413         1  0.169231       0.253381          23420
#
# ...

# %%
dane.describe(include=[np.number])
# Out:
#                Age    Attrition  BusinessTravel   Department  \
# count  4382.000000  4382.000000     4382.000000  4382.000000
# mean     36.933364     0.160885        0.160885     0.160885
# std       9.137272     0.367467        0.046469     0.028248
# min      18.000000     0.000000        0.080357     0.151128
# 25%      30.000000     0.000000        0.149566     0.151128
# 50%      36.000000     0.000000        0.149566     0.156719
# 75%      43.000000     0.000000        0.149566     0.156719
# max      60.000000     1.000000        0.247273     0.294118
#
#        DistanceFromHome    Education  EducationField       Gender  \
# count       4382.000000  4382.000000     4382.000000  4382.000000
# mean           9.198996     2.912369        0.160885     0.160885
# std            8.105396     1.024728        0.036457     0.006760
# min            1.000000     1.000000        0.114796     0.152620
# 25%            2.000000     2.000000        0.157895     0.152620
# ...

# %%
y = dane.Attrition
X = dane.drop(['Attrition'], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression(solver='lbfgs')
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = logisticRegr.predict(x_test)
proba = logisticRegr.predict_proba(x_test)
f = pd.DataFrame(proba)
f.describe()
# Out:
#                  0            1
# count  1315.000000  1315.000000
# mean      0.846820     0.153180
# std       0.049503     0.049503
# min       0.688060     0.042467
# 25%       0.810817     0.116769
# 50%       0.848070     0.151930
# 75%       0.883231     0.189183
# max       0.957533     0.311940

# %%
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.8182509505703423

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
cm = confusion_matrix(y_test, predictions)
print(cm)
# Out:
# [[1076    0]
#  [ 239    0]]
