# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Python, Julia, R, SQL

# %% [markdown]
# Scikit-learn, TensorFlow, PyTorch

# %% [markdown]
# | Data Science tools |
# |:--------:|
# |  VS Code |
# |  SQL     |
# |  Python  |
# |  Git     |
# |  R     |

# %% [markdown]
# #### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#  This a simple arithmetic expression to mutiply then add integers
1 / 2 + 3 // 3 + 4 ** 2
# Out:
# 17.5

# %%
# This will convert 120 minutes to hours by diving by 60
120/60
# Out:
# 2.0

# %% [markdown]
# Objectives
#
# - Extract insights from data to support decision-making
# - Build predictive models to forecast future outcomes
# - Identify patterns and trends in large datasets
# - Improve business processes using data-driven optimization
# - Segment customers for personalized marketing and services
# - Detect anomalies and prevent fraud or operational issues
# - Automate decision-making with machine learning
# - Evaluate and monitor model performance over time
# - Communicate findings clearly to stakeholders

# %% [markdown]
# ### Author
# Krzysztof Bruszewski
